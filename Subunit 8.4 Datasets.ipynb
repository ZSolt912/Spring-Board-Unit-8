# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
appledescription = pd.read_csv(r"C:\Users\zsoltani\Downloads\Unit 8 SpringBoard\appleStore_description.csv")
Apple = pd.read_csv(r"C:\Users\zsoltani\Downloads\Unit 8 SpringBoard\AppleStore.csv")
Google = pd.read_csv(r"C:\Users\zsoltani\Downloads\Unit 8 SpringBoard\googleplaystore.csv")
Googlereview = pd.read_csv(r"C:\Users\zsoltani\Downloads\Unit 8 SpringBoard\googleplaystore_user_reviews.csv")
Apple_top= Apple.head(5)
Google_top= Google.head(5)
Google_top
Apple_top
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
Google_top
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
google=Google[['Category', 'Rating', 'Reviews', 'Price']]
google
# Out:
#                   Category  Rating Reviews Price
# 0           ART_AND_DESIGN     4.1     159     0
# 1           ART_AND_DESIGN     3.9     967     0
# 2           ART_AND_DESIGN     4.7   87510     0
# 3           ART_AND_DESIGN     4.5  215644     0
# 4           ART_AND_DESIGN     4.3     967     0
# ...                    ...     ...     ...   ...
# 10836               FAMILY     4.5      38     0
# 10837               FAMILY     5.0       4     0
# 10838              MEDICAL     NaN       3     0
# 10839  BOOKS_AND_REFERENCE     4.5     114     0
# 10840            LIFESTYLE     4.5  398307     0
#
# [10841 rows x 4 columns]

# %%
apple=Apple[['prime_genre', 'user_rating','rating_count_tot','price']]
apple
# Out:
#        prime_genre  user_rating  rating_count_tot  price
# 0            Games          4.0             21292   3.99
# 1     Productivity          4.0            161065   0.00
# 2          Weather          3.5            188583   0.00
# 3         Shopping          4.0            262241   0.00
# 4        Reference          4.5            985920   0.00
# ...            ...          ...               ...    ...
# 7192         Games          4.5               142   0.00
# 7193         Games          4.5                30   0.00
# 7194     Utilities          4.5                15   1.99
# 7195         Games          4.5                85   0.00
# 7196         Games          5.0                 3   0.00
#
# [7197 rows x 4 columns]

# %%
apple.dtypes
# Out:
# prime_genre          object
# user_rating         float64
# rating_count_tot      int64
# price               float64
# dtype: object

# %%
google.dtypes
# Out:
# Category     object
# Rating      float64
# Reviews      object
# Price        object
# dtype: object

# %%
google['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
Google[Google['Price']=='Everyone']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# eliminate the row including "Everyone"
google = google[google['Price'] !='Everyone']
google
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e0592ff7081e> in <module>
#       1 # eliminate the row including "Everyone"
# ----> 2 google = google[google['Price'] !='Everyone']
#       3 google
#
# NameError: name 'google' is not defined

# %%
google['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
# we want to find '$' and replace it with nothing.
nosymb = google['Price'].str.replace('$','' )

# %%
google['Price'] = pd.to_numeric(nosymb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-0e2c5f1e5eff> in <module>
# ----> 1 google['Price'] = pd.to_numeric(nosymb)
#
# NameError: name 'nosymb' is not defined

# %%
google.dtypes
# Out:
# Category     object
# Rating      float64
# Reviews      object
# Price        object
# dtype: object

# %%
#Add a platform column to both the Apple and the Google dataframes
apple['Platform'] = 'apple'
google['Platform'] = 'google'
# Out:
# C:\Users\zsoltani\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\zsoltani\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
apple
# Out:
#           Category  Rating  Reviews  Price Platform
# 0            Games     4.0    21292   3.99    apple
# 1     Productivity     4.0   161065   0.00    apple
# 2          Weather     3.5   188583   0.00    apple
# 3         Shopping     4.0   262241   0.00    apple
# 4        Reference     4.5   985920   0.00    apple
# ...            ...     ...      ...    ...      ...
# 7192         Games     4.5      142   0.00    apple
# 7193         Games     4.5       30   0.00    apple
# 7194     Utilities     4.5       15   1.99    apple
# 7195         Games     4.5       85   0.00    apple
# 7196         Games     5.0        3   0.00    apple
#
# [7197 rows x 5 columns]

# %%
google
# Out:
#                   Category  Rating Reviews Price Platform
# 0           ART_AND_DESIGN     4.1     159     0   google
# 1           ART_AND_DESIGN     3.9     967     0   google
# 2           ART_AND_DESIGN     4.7   87510     0   google
# 3           ART_AND_DESIGN     4.5  215644     0   google
# 4           ART_AND_DESIGN     4.3     967     0   google
# ...                    ...     ...     ...   ...      ...
# 10836               FAMILY     4.5      38     0   google
# 10837               FAMILY     5.0       4     0   google
# 10838              MEDICAL     NaN       3     0   google
# 10839  BOOKS_AND_REFERENCE     4.5     114     0   google
# 10840            LIFESTYLE     4.5  398307     0   google
#
# [10841 rows x 5 columns]

# %%
apple.rename(columns={'prime_genre': 'Category','user_rating':'Rating','rating_count_tot':'Reviews','price':'Price'},inplace=True)
apple
# Out:
# C:\Users\zsoltani\Anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#           Category  Rating  Reviews  Price Platform
# 0            Games     4.0    21292   3.99    apple
# 1     Productivity     4.0   161065   0.00    apple
# 2          Weather     3.5   188583   0.00    apple
# 3         Shopping     4.0   262241   0.00    apple
# 4        Reference     4.5   985920   0.00    apple
# ...            ...     ...      ...    ...      ...
# 7192         Games     4.5      142   0.00    apple
# 7193         Games     4.5       30   0.00    apple
# 7194     Utilities     4.5       15   1.99    apple
# 7195         Games     4.5       85   0.00    apple
# 7196         Games     5.0        3   0.00    apple
#
# ...

# %%
df = google.append(apple,ignore_index= True)
df.sample(12)
# Out:
#                  Category  Rating Reviews Price Platform
# 7671              FINANCE     3.6     180     0   google
# 14260               Games     4.5     380  0.99    apple
# 9380                 GAME     4.4    1294     0   google
# 3731   NEWS_AND_MAGAZINES     4.4    1071     0   google
# 4267                TOOLS     3.5   81747     0   google
# 7177             BUSINESS     3.8      70     0   google
# 15494               Games     3.5      27  3.99    apple
# 13873           Education     4.5     977     0    apple
# 15926   Social Networking     0.0       0     0    apple
# 6379   HEALTH_AND_FITNESS     2.2       4     0   google
# 15000           Lifestyle     0.0       0     0    apple
# 17973               Games     0.0       0     0    apple

# %%
print(df.shape)
# Out:
# (18038, 5)

# %%
df =  df.dropna()
print(df.shape)
# Out:
# (16564, 5)

# %%
df=df[df['Reviews']!=0]
df
# Out:
#              Category  Rating Reviews Price Platform
# 0      ART_AND_DESIGN     4.1     159     0   google
# 1      ART_AND_DESIGN     3.9     967     0   google
# 2      ART_AND_DESIGN     4.7   87510     0   google
# 3      ART_AND_DESIGN     4.5  215644     0   google
# 4      ART_AND_DESIGN     4.3     967     0   google
# ...               ...     ...     ...   ...      ...
# 18033           Games     4.5     142     0    apple
# 18034           Games     4.5      30     0    apple
# 18035       Utilities     4.5      15  1.99    apple
# 18036           Games     4.5      85     0    apple
# 18037           Games     5.0       3     0    apple
#
# [15635 rows x 5 columns]

# %%
df[df['Reviews'] == 0].count()
print(df.shape)
# Out:
# (15635, 4)

# %%
df.groupby(by='Platform')['Rating'].describe()
# Out:
#            count      mean       std  min  25%  50%  75%   max
# Platform
# apple     6268.0  4.049697  0.726943  1.0  4.0  4.5  4.5   5.0
# google    9367.0  4.193338  0.537431  1.0  4.0  4.3  4.5  19.0

# %%
df.boxplot(by='Platform', column =['Rating'], grid=False, rot=45, fontsize=15)

# %%
apple = df[df['Platform'] == 'apple']['Rating']
google = df[df['Platform'] == 'google']['Rating']

# %%
from scipy import stats
apple_normal = stats.normaltest(apple)
print(apple_normal)
# Out:
# NormaltestResult(statistic=1778.9974234584017, pvalue=0.0)

# %%
google_normal = stats.normaltest(google)
print(google_normal)
# Out:
# NormaltestResult(statistic=3827.068666333558, pvalue=0.0)

# %%
histoApple = plt.hist(apple)

# %%
histoGoogle = plt.hist(google)

# %%
df['Permutation1'] = np.random.permutation(df['Rating'])

# %%
df.groupby(by='Platform')['Permutation1'].describe()
# Out:
#            count      mean       std  min  25%  50%  75%   max
# Platform
# apple     6268.0  4.137795  0.637979  1.0  4.0  4.3  4.5  19.0
# google    9367.0  4.134387  0.615102  1.0  4.0  4.3  4.5   5.0

# %%
df.groupby(by='Platform')['Rating'].describe()
# Out:
#            count      mean       std  min  25%  50%  75%   max
# Platform
# apple     6268.0  4.049697  0.726943  1.0  4.0  4.5  4.5   5.0
# google    9367.0  4.193338  0.537431  1.0  4.0  4.3  4.5  19.0

# %%
difference = list()
for i in range(10000):
    permutation = np.random.permutation(df['Rating'])
    difference.append(np.mean(permutation[df['Platform']=='apple']) - np.mean(permutation[df['Platform']=='google']))

# %%
histo = plt.hist(difference)

# %%
obs_difference = np.mean(df['Platform']=='apple') - np.mean(df['Platform']=='google')

# %%
obs_difference = abs(obs_difference)

# %%
obs_difference
# Out:
# 0.1982091461464663
